# %%
import ScaleFEx_class
import numpy as np
import os
path_to_images=os.path.join(os.getcwd(),'data/') # Data path of the images.The code will look for a folder per experiment
                          # The structure would be /folder_path/experiment_name*Platen*/Images/*.tif
saving_folder=os.path.join(os.getcwd(),'output/') #folder where the csv containing the measurements is saved
                                #It will create a folder called 'FeatureVector' in the saving folder
experiment_name='ScaleFEx_Dataset01' #experiment name, it will look for it in the filepath
plates=['Plate1'] #Plate names, it will look for it in the filepath
ROI=75  #radius to define the crop-size 
channels=['ch4','ch1','ch2','ch3','ch5'] #channels to be analysed and in that order. 
                                         #DNA should be first as it defines the center of the crop 
MitoCh='ch2'  # Mitochondria channel. If you don't want to compute the Mito fearues, put ''
RNAch='ch5'   # RNA channel. If you don't want to compute the RNA fearues, put ''
image_size=[1080,1080] # X-Y image size
downsampling=1  # downsampling ratio
parallel=True   # parallelization flag. If True, it will parallelaize the computation over 6 workers
visualization=True # Visualizatin flag: change it to True if you want to see all the computed masks
SaveImage=False # Put True if you want to save the crops as .npy in a folder
stack=False  # Indicate here if the images were acquired in stacks
magnification=40 # magnification of the images
CellType='Fibroblast'   #types of cells in the screen. Used mainly in the segmentation portion. Inputs: 'Neuron', 'iPSC'


img=ScaleFEx_class.ScaleFEx(path_to_images,saving_folder=saving_folder,experiment_name=experiment_name,
                        Plates=plates,Channel=channels,ROI=ROI,visualization=visualization,
                        img_size=image_size,parallel=parallel,SaveImage=SaveImage,stack=stack, mag=magnification, 
                        CellType=CellType,MitoCh=MitoCh,RNAch=RNAch,downsampling=downsampling,)
# Out:
# Loading FFC image
# r03c03 Plate1 2023-03-23 10:38:47.911149
# f01 r03c03 Plate1 2023-03-23 10:38:47.952731
# [142.28333333333333, 532.4633333333334]
# [153.5535428875866, 335.92115077250935]
# [366.3311582381729, 381.16313213703097]
# [453.3401838831801, 123.82152514872904]
# [485.02801867911944, 329.3455637091394]
# [611.3017088980554, 87.77253977607543]
# [750.2895574197281, 664.0650853341048]
# [881.0168634064081, 1002.5064643057898]
# [872.4319682959049, 243.14927344782035]
# [945.9106844741235, 358.84348914858094]
# [948.4607355864811, 109.65009940357852]
